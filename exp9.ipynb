# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=dataset,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxenplot(data=dataset,x='sex',y='age')
# Out:
# C:\Users\jadha\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jadha\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8,10))
sns.boxplot(data=dataset,x='sex',y='age',hue='survived')
plt.show()

# %%
sns.boxplot(data=dataset,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.catplot(data=dataset,x='sex',kind="count",hue='survived')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sns.catplot(data=dataset,x='sex',kind="count",hue='survived')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
#    3247     g.set_axis_labels(p.value_label, p.group_label)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
# ...
